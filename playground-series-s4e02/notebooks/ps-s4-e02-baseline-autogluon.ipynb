# %%
import pandas as pd
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
#global variables

SEED = 42
TARGET = 'NObeyesdad'
FILEPATH = '../data/'

# %%
train_df =pd.read_csv(f"{FILEPATH}train.csv")
test_df = pd.read_csv(f"{FILEPATH}test.csv")
original_df = pd.read_csv(f"{FILEPATH}ObesityDataSet.csv")

test_ids = test_df["id"]
test_df = test_df.drop(["id"], axis = 1)
train_df = train_df.drop(["id"], axis = 1)


display(train_df.head())
display(original_df.head())
display(train_df.shape)
display(original_df.shape)
# Get the unique columns from each data frame
train_columns = set(train_df.columns)
original_columns = set(original_df.columns)

# Find the difference in columns
difference_columns = train_columns.symmetric_difference(original_columns)

# Display the difference in columns
print("Columns present in train_df but not in original_df:")
print(difference_columns.intersection(train_columns))
print("\nColumns present in original_df but not in train_df:")
print(difference_columns.intersection(original_columns))


train_df = pd.concat([train_df, original_df], ignore_index=True)
display(train_df.head())
display(train_df.shape)
# Out:
#    Gender        Age    Height      Weight family_history_with_overweight  \
# 0    Male  24.443011  1.699998   81.669950                            yes
# 1  Female  18.000000  1.560000   57.000000                            yes
# 2  Female  18.000000  1.711460   50.165754                            yes
# 3  Female  20.952737  1.710730  131.274851                            yes
# 4    Male  31.641081  1.914186   93.798055                            yes
#
#   FAVC      FCVC       NCP        CAEC SMOKE      CH2O SCC       FAF  \
# 0  yes  2.000000  2.983297   Sometimes    no  2.763573  no  0.000000
# 1  yes  2.000000  3.000000  Frequently    no  2.000000  no  1.000000
# 2  yes  1.880534  1.411685   Sometimes    no  1.910378  no  0.866045
# 3  yes  3.000000  3.000000   Sometimes    no  1.674061  no  1.467863
# 4  yes  2.679664  1.971472   Sometimes    no  1.979848  no  1.967973
#
#         TUE       CALC                 MTRANS           NObeyesdad
# 0  0.976473  Sometimes  Public_Transportation  Overweight_Level_II
# 1  1.000000         no             Automobile        Normal_Weight
# 2  1.673584         no  Public_Transportation  Insufficient_Weight
# 3  0.780199  Sometimes  Public_Transportation     Obesity_Type_III
# 4  0.931721  Sometimes  Public_Transportation  Overweight_Level_II
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# 2  Public_Transportation        Normal_Weight
# 3                Walking   Overweight_Level_I
# 4  Public_Transportation  Overweight_Level_II
# (20758, 17)
# (2111, 17)
# Columns present in train_df but not in original_df:
# set()
#
# Columns present in original_df but not in train_df:
# set()
#    Gender        Age    Height      Weight family_history_with_overweight  \
# 0    Male  24.443011  1.699998   81.669950                            yes
# 1  Female  18.000000  1.560000   57.000000                            yes
# 2  Female  18.000000  1.711460   50.165754                            yes
# 3  Female  20.952737  1.710730  131.274851                            yes
# 4    Male  31.641081  1.914186   93.798055                            yes
#
#   FAVC      FCVC       NCP        CAEC SMOKE      CH2O SCC       FAF  \
# 0  yes  2.000000  2.983297   Sometimes    no  2.763573  no  0.000000
# 1  yes  2.000000  3.000000  Frequently    no  2.000000  no  1.000000
# 2  yes  1.880534  1.411685   Sometimes    no  1.910378  no  0.866045
# 3  yes  3.000000  3.000000   Sometimes    no  1.674061  no  1.467863
# 4  yes  2.679664  1.971472   Sometimes    no  1.979848  no  1.967973
#
#         TUE       CALC                 MTRANS           NObeyesdad
# 0  0.976473  Sometimes  Public_Transportation  Overweight_Level_II
# 1  1.000000         no             Automobile        Normal_Weight
# 2  1.673584         no  Public_Transportation  Insufficient_Weight
# 3  0.780199  Sometimes  Public_Transportation     Obesity_Type_III
# 4  0.931721  Sometimes  Public_Transportation  Overweight_Level_II
# (22869, 17)

# %%
def analyze_dataframe(df):
    """
    Analyze a pandas DataFrame and provide a summary of its characteristics.

    Parameters:
    df (pandas.DataFrame): The input DataFrame to analyze.

    Returns:
    None
    """
    print("DataFrame Information:")
    print("______________________")
    display(df.info(verbose=True, show_counts=True))
    print("\n")
    
    print("DataFrame Head:")
    print("______________________")
    display(df.head())
    print("\n")

    print("DataFrame Tail:")
    print("______________________")
    display(df.tail())
    print("\n")

    print("DataFrame Description:")
    print("______________________")
    display(df.describe().T)
    print("\n")

    print("Number of Null Values:")
    print("______________________")
    display(df.isnull().sum())
    print("\n")

    print("Number of Duplicated Rows:")
    print("______________________")
    display(df.duplicated().sum())
    print("\n")

    print("Number of Unique Values:")
    print("______________________")
    display(df.nunique())
    print("\n")

    print("DataFrame Shape:")
    print("______________________")
    print(f"Rows: {df.shape[0]}, Columns: {df.shape[1]}")
    print("\n")
    
    print("DataFrame Columns:")
    print("______________________")
    display(df.columns)
    

analyze_dataframe(train_df)
# Out:
# DataFrame Information:
# ______________________
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22869 entries, 0 to 22868
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          22869 non-null  object
#  1   Age                             22869 non-null  float64
#  2   Height                          22869 non-null  float64
#  3   Weight                          22869 non-null  float64
#  4   family_history_with_overweight  22869 non-null  object
#  5   FAVC                            22869 non-null  object
#  6   FCVC                            22869 non-null  float64
#  7   NCP                             22869 non-null  float64
#  8   CAEC                            22869 non-null  object
#  9   SMOKE                           22869 non-null  object
#  10  CH2O                            22869 non-null  float64
#  11  SCC                             22869 non-null  object
#  12  FAF                             22869 non-null  float64
#  13  TUE                             22869 non-null  float64
#  14  CALC                            22869 non-null  object
#  15  MTRANS                          22869 non-null  object
#  16  NObeyesdad                      22869 non-null  object
# dtypes: float64(8), object(9)
# memory usage: 3.0+ MB
# None
# DataFrame Head:
# ______________________
#    Gender        Age    Height      Weight family_history_with_overweight  \
# 0    Male  24.443011  1.699998   81.669950                            yes
# 1  Female  18.000000  1.560000   57.000000                            yes
# 2  Female  18.000000  1.711460   50.165754                            yes
# 3  Female  20.952737  1.710730  131.274851                            yes
# 4    Male  31.641081  1.914186   93.798055                            yes
#
#   FAVC      FCVC       NCP        CAEC SMOKE      CH2O SCC       FAF  \
# 0  yes  2.000000  2.983297   Sometimes    no  2.763573  no  0.000000
# 1  yes  2.000000  3.000000  Frequently    no  2.000000  no  1.000000
# 2  yes  1.880534  1.411685   Sometimes    no  1.910378  no  0.866045
# 3  yes  3.000000  3.000000   Sometimes    no  1.674061  no  1.467863
# 4  yes  2.679664  1.971472   Sometimes    no  1.979848  no  1.967973
#
#         TUE       CALC                 MTRANS           NObeyesdad
# 0  0.976473  Sometimes  Public_Transportation  Overweight_Level_II
# 1  1.000000         no             Automobile        Normal_Weight
# 2  1.673584         no  Public_Transportation  Insufficient_Weight
# 3  0.780199  Sometimes  Public_Transportation     Obesity_Type_III
# 4  0.931721  Sometimes  Public_Transportation  Overweight_Level_II
# DataFrame Tail:
# ______________________
#        Gender        Age    Height      Weight family_history_with_overweight  \
# 22864  Female  20.976842  1.710730  131.408528                            yes
# 22865  Female  21.982942  1.748584  133.742943                            yes
# 22866  Female  22.524036  1.752206  133.689352                            yes
# 22867  Female  24.361936  1.739450  133.346641                            yes
# 22868  Female  23.664709  1.738836  133.472641                            yes
#
#       FAVC  FCVC  NCP       CAEC SMOKE      CH2O SCC       FAF       TUE  \
# 22864  yes   3.0  3.0  Sometimes    no  1.728139  no  1.676269  0.906247
# 22865  yes   3.0  3.0  Sometimes    no  2.005130  no  1.341390  0.599270
# 22866  yes   3.0  3.0  Sometimes    no  2.054193  no  1.414209  0.646288
# 22867  yes   3.0  3.0  Sometimes    no  2.852339  no  1.139107  0.586035
# 22868  yes   3.0  3.0  Sometimes    no  2.863513  no  1.026452  0.714137
#
#             CALC                 MTRANS        NObeyesdad
# 22864  Sometimes  Public_Transportation  Obesity_Type_III
# 22865  Sometimes  Public_Transportation  Obesity_Type_III
# 22866  Sometimes  Public_Transportation  Obesity_Type_III
# 22867  Sometimes  Public_Transportation  Obesity_Type_III
# 22868  Sometimes  Public_Transportation  Obesity_Type_III
# DataFrame Description:
# ______________________
#           count       mean        std    min        25%        50%  \
# Age     22869.0  23.885263   5.753419  14.00  20.000000  22.815416
# Height  22869.0   1.700377   0.087881   1.45   1.631662   1.700000
# Weight  22869.0  87.767610  26.364243  39.00  66.000000  84.000000
# FCVC    22869.0   2.443428   0.533329   1.00   2.000000   2.392665
# NCP     22869.0   2.754344   0.712711   1.00   3.000000   3.000000
# CH2O    22869.0   2.027442   0.608901   1.00   1.755907   2.000000
# FAF     22869.0   0.984382   0.839466   0.00   0.015860   1.000000
# TUE     22869.0   0.620551   0.602850   0.00   0.000000   0.579541
#
#                75%     max
# Age      26.000000   61.00
# Height    1.763029    1.98
# Weight  111.531208  173.00
# FCVC      3.000000    3.00
# NCP       3.000000    4.00
# CH2O      2.535127    3.00
# FAF       1.596576    3.00
# TUE       1.000000    2.00
# Number of Null Values:
# ______________________
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64
# Number of Duplicated Rows:
# ______________________
# 24
# Number of Unique Values:
# ______________________
# Gender                               2
# Age                               1739
# Height                            1862
# Weight                            2014
# family_history_with_overweight       2
# FAVC                                 2
# FCVC                               975
# NCP                                740
# CAEC                                 4
# SMOKE                                2
# CH2O                              1568
# SCC                                  2
# FAF                               1408
# TUE                               1329
# CALC                                 4
# MTRANS                               5
# NObeyesdad                           7
# dtype: int64
# DataFrame Shape:
# ______________________
# Rows: 22869, Columns: 17
#
#
# DataFrame Columns:
# ______________________
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
def feature_eng(train_df, test_df):
    # Function to calculate BMI
    def calculate_bmi(df):
        df['BMI'] = df['Weight'] / (df['Height'] ** 2)
        return df
    
    # Function to categorize BMI
    def categorize_bmi(bmi):
        if bmi < 18.5:
            return 'Underweight'
        elif bmi < 25:
            return 'Normal weight'
        elif bmi < 30:
            return 'Overweight'
        else:
            return 'Obese'
    
    # Function to categorize age
    def categorize_age(age):
        if age < 26:
            return '18-25'
        elif age < 36:
            return '26-35'
        elif age < 46:
            return '36-45'
        elif age < 56:
            return '46-55'
        else:
            return '56+'
    
    # Function to categorize TUE (Technology Use)
    def categorize_tue(tue):
        if tue <= 1:
            return 'Low'
        elif tue <= 2:
            return 'Medium'
        else:
            return 'High'

    # Apply the functions to both train and test datasets
    for df in [train_df, test_df]:
        df = calculate_bmi(df)
        #df['Weight_Category'] = df['BMI'].apply(categorize_bmi)
        # df['Age_Group'] = df['Age'].apply(categorize_age)
        # df['Physical_Health_Score'] = df[['FCVC', 'FAF', 'CH2O', 'NCP']].mean(axis=1)
        # df['TUE_Score'] = df['TUE'].apply(categorize_tue)

    return train_df, test_df
feature_eng(train_df, test_df)
train_df.head()
# Out:
#    Gender        Age    Height      Weight family_history_with_overweight  \
# 0    Male  24.443011  1.699998   81.669950                            yes
# 1  Female  18.000000  1.560000   57.000000                            yes
# 2  Female  18.000000  1.711460   50.165754                            yes
# 3  Female  20.952737  1.710730  131.274851                            yes
# 4    Male  31.641081  1.914186   93.798055                            yes
#
#   FAVC      FCVC       NCP        CAEC SMOKE      CH2O SCC       FAF  \
# 0  yes  2.000000  2.983297   Sometimes    no  2.763573  no  0.000000
# 1  yes  2.000000  3.000000  Frequently    no  2.000000  no  1.000000
# 2  yes  1.880534  1.411685   Sometimes    no  1.910378  no  0.866045
# 3  yes  3.000000  3.000000   Sometimes    no  1.674061  no  1.467863
# 4  yes  2.679664  1.971472   Sometimes    no  1.979848  no  1.967973
#
#         TUE       CALC                 MTRANS           NObeyesdad        BMI
# 0  0.976473  Sometimes  Public_Transportation  Overweight_Level_II  28.259565
# 1  1.000000         no             Automobile        Normal_Weight  23.422091
# 2  1.673584         no  Public_Transportation  Insufficient_Weight  17.126706
# 3  0.780199  Sometimes  Public_Transportation     Obesity_Type_III  44.855798
# 4  0.931721  Sometimes  Public_Transportation  Overweight_Level_II  25.599151

# %%
train = TabularDataset(train_df)
test = TabularDataset(test_df)
#time_limit = 3600
metric = 'accuracy'
predictor = TabularPredictor(label=TARGET, eval_metric=metric).fit(train,presets='best_quality')
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20240202_050623"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Dynamic stacking is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# Detecting stacked overfitting by sub-fitting AutoGluon on the input data. That is, copies of AutoGluon will be sub-fit on subset(s) of the data. Then, the holdout validation data is used to detect stacked overfitting.
# Sub-fit(s) time limit is: 3600 seconds.
# Starting holdout-based sub-fit for dynamic stacking. Context path is: AutogluonModels\ag-20240202_050623/ds_sub_fit/sub_fit_ho.
# Running the sub-fit in a ray process to avoid memory leakage.
# Spend 931 seconds for the sub-fit(s) during dynamic stacking.
# Time left for full fit of AutoGluon: 2669 seconds.
# Starting full fit now with num_stack_levels 0.
# Beginning AutoGluon training ... Time limit = 2669s
# AutoGluon will save models to "AutogluonModels\ag-20240202_050623"
# =================== System Info ===================
# AutoGluon Version:  1.0.0
# Python Version:     3.10.13
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          32
# Memory Avail:       101.68 GB / 127.91 GB (79.5%)
# Disk Space Avail:   2733.02 GB / 7452.02 GB (36.7%)
# ===================================================
# Train Data Rows:    22869
# Train Data Columns: 17
# Label Column:       NObeyesdad
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 7
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    104132.79 MB
# 	Train Data (Original)  Memory Usage: 12.60 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 5 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 9 | ['Age', 'Height', 'Weight', 'FCVC', 'NCP', ...]
# 		('object', []) : 8 | ['Gender', 'family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 3 | ['CAEC', 'CALC', 'MTRANS']
# 		('float', [])     : 9 | ['Age', 'Height', 'Weight', 'FCVC', 'NCP', ...]
# 		('int', ['bool']) : 5 | ['Gender', 'family_history_with_overweight', 'FAVC', 'SMOKE', 'SCC']
# 	0.2s = Fit runtime
# 	17 features in original data used to generate 17 features in processed data.
# 	Train Data (Processed) Memory Usage: 1.75 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.27s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 2668.73s of the 2668.72s of remaining time.
# 	0.8782	 = Validation score   (accuracy)
# 	0.1s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 2668.37s of the 2668.35s of remaining time.
# 	0.8762	 = Validation score   (accuracy)
# 	0.11s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2668.01s of the 2668.0s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.02%)
# 	0.8944	 = Validation score   (accuracy)
# 	41.2s	 = Training   runtime
# 	0.53s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2617.35s of the 2617.33s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.02%)
# 	0.9101	 = Validation score   (accuracy)
# 	7.55s	 = Training   runtime
# 	0.73s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2595.3s of the 2595.28s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.02%)
# 	0.9141	 = Validation score   (accuracy)
# 	6.88s	 = Training   runtime
# 	0.52s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 2576.17s of the 2576.15s of remaining time.
# 	0.9073	 = Validation score   (accuracy)
# 	1.38s	 = Training   runtime
# 	0.81s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 2573.58s of the 2573.57s of remaining time.
# 	0.9082	 = Validation score   (accuracy)
# 	1.44s	 = Training   runtime
# 	0.8s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 2570.96s of the 2570.94s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.02%)
# 	0.9133	 = Validation score   (accuracy)
# 	472.35s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 2086.17s of the 2086.15s of remaining time.
# 	0.9055	 = Validation score   (accuracy)
# 	1.18s	 = Training   runtime
# 	0.9s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 2083.59s of the 2083.58s of remaining time.
# 	0.9058	 = Validation score   (accuracy)
# 	1.18s	 = Training   runtime
# 	0.9s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 2080.75s of the 2080.74s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.02%)
# 	0.9156	 = Validation score   (accuracy)
# 	7.24s	 = Training   runtime
# 	0.61s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 2061.82s of the 2061.81s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	0.8923	 = Validation score   (accuracy)
# 	81.91s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 1970.05s of the 1970.03s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.03%)
# 	0.9122	 = Validation score   (accuracy)
# 	14.79s	 = Training   runtime
# 	0.79s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 1944.82s of the 1944.81s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.02%)
# 	0.9149	 = Validation score   (accuracy)
# 	36.65s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 1900.78s of the 1900.76s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	0.892	 = Validation score   (accuracy)
# 	116.31s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 1773.12s of the 1773.1s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.02%)
# 	0.915	 = Validation score   (accuracy)
# 	14.2s	 = Training   runtime
# 	1.26s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 1748.49s of the 1748.47s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.02%)
# 	0.8958	 = Validation score   (accuracy)
# 	116.5s	 = Training   runtime
# 	0.83s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 1624.55s of the 1624.54s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.04%)
# 	0.9136	 = Validation score   (accuracy)
# 	478.77s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 1132.72s of the 1132.71s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	0.9118	 = Validation score   (accuracy)
# 	33.21s	 = Training   runtime
# 	13.75s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 1085.48s of the 1085.47s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	0.894	 = Validation score   (accuracy)
# 	127.92s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 945.29s of the 945.27s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.06%)
# 	0.9139	 = Validation score   (accuracy)
# 	24.15s	 = Training   runtime
# 	3.2s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 911.11s of the 911.09s of remaining time.
# 	0.9054	 = Validation score   (accuracy)
# 	1.29s	 = Training   runtime
# 	0.82s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 908.54s of the 908.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.01%)
# 	0.913	 = Validation score   (accuracy)
# 	652.47s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 244.5s of the 244.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.02%)
# 	0.8942	 = Validation score   (accuracy)
# 	16.47s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 217.17s of the 217.15s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.04%)
# 	0.9103	 = Validation score   (accuracy)
# 	173.85s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 32.84s of the 32.82s of remaining time.
# 	0.9034	 = Validation score   (accuracy)
# 	2.52s	 = Training   runtime
# 	0.8s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 29.15s of the 29.14s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=4, gpus=0, memory=0.02%)
# 	0.9069	 = Validation score   (accuracy)
# 	18.19s	 = Training   runtime
# 	1.41s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the -0.68s of remaining time.
# 	Ensemble Weights: {'XGBoost_BAG_L1': 1.0}
# 	0.9156	 = Validation score   (accuracy)
# 	9.43s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2679.18s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20240202_050623")

# %%
predictor.leaderboard()
# Out:
#                           model  score_val eval_metric  pred_time_val  \
# 0                XGBoost_BAG_L1   0.915606    accuracy       0.610375
# 1           WeightedEnsemble_L2   0.915606    accuracy       0.613376
# 2          LightGBM_r131_BAG_L1   0.914950    accuracy       1.261302
# 3          CatBoost_r177_BAG_L1   0.914863    accuracy       0.146517
# 4               LightGBM_BAG_L1   0.914076    accuracy       0.515129
# 5            XGBoost_r33_BAG_L1   0.913901    accuracy       3.195223
# 6            CatBoost_r9_BAG_L1   0.913551    accuracy       0.170912
# 7               CatBoost_BAG_L1   0.913289    accuracy       0.123014
# 8          CatBoost_r137_BAG_L1   0.913026    accuracy       0.133456
# 9          LightGBMLarge_BAG_L1   0.912196    accuracy       0.786487
# 10          LightGBM_r96_BAG_L1   0.911802    accuracy      13.753068
# 11          CatBoost_r13_BAG_L1   0.910315    accuracy       0.166595
# 12            LightGBMXT_BAG_L1   0.910097    accuracy       0.732612
# 13      RandomForestEntr_BAG_L1   0.908216    accuracy       0.803535
# 14      RandomForestGini_BAG_L1   0.907254    accuracy       0.810867
# 15         LightGBM_r188_BAG_L1   0.906948    accuracy       1.411505
# 16        ExtraTreesEntr_BAG_L1   0.905768    accuracy       0.895795
# 17        ExtraTreesGini_BAG_L1   0.905549    accuracy       0.899859
# 18        ExtraTrees_r42_BAG_L1   0.905418    accuracy       0.824983
# 19     RandomForest_r195_BAG_L1   0.903406    accuracy       0.804935
# 20  NeuralNetFastAI_r191_BAG_L1   0.895754    accuracy       0.830017
# 21       NeuralNetFastAI_BAG_L1   0.894355    accuracy       0.525837
# 22  NeuralNetFastAI_r102_BAG_L1   0.894224    accuracy       0.228251
# 23    NeuralNetTorch_r22_BAG_L1   0.894005    accuracy       0.357672
# 24        NeuralNetTorch_BAG_L1   0.892256    accuracy       0.195346
# 25    NeuralNetTorch_r79_BAG_L1   0.891994    accuracy       0.293587
# 26        KNeighborsUnif_BAG_L1   0.878219    accuracy       0.179275
# 27        KNeighborsDist_BAG_L1   0.876164    accuracy       0.175317
#
#       fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
# 0     7.240405                0.610375           7.240405            1
# 1    16.671512                0.003000           9.431107            2
# 2    14.196565                1.261302          14.196565            1
# 3    36.654822                0.146517          36.654822            1
# 4     6.879381                0.515129           6.879381            1
# 5    24.151040                3.195223          24.151040            1
# 6   478.774273                0.170912         478.774273            1
# 7   472.346310                0.123014         472.346310            1
# 8   652.472127                0.133456         652.472127            1
# 9    14.792836                0.786487          14.792836            1
# 10   33.207987               13.753068          33.207987            1
# 11  173.854922                0.166595         173.854922            1
# 12    7.551321                0.732612           7.551321            1
# 13    1.440816                0.803535           1.440816            1
# 14    1.380393                0.810867           1.380393            1
# 15   18.187902                1.411505          18.187902            1
# 16    1.176075                0.895795           1.176075            1
# 17    1.176808                0.899859           1.176808            1
# 18    1.291222                0.824983           1.291222            1
# 19    2.522972                0.804935           2.522972            1
# 20  116.499708                0.830017         116.499708            1
# 21   41.201330                0.525837          41.201330            1
# 22   16.465232                0.228251          16.465232            1
# 23  127.922934                0.357672         127.922934            1
# 24   81.913659                0.195346          81.913659            1
# 25  116.310194                0.293587         116.310194            1
# 26    0.103999                0.179275           0.103999            1
# 27    0.106815                0.175317           0.106815            1
#
#     can_infer  fit_order
# 0        True         11
# 1        True         28
# 2        True         16
# 3        True         14
# 4        True          5
# 5        True         21
# 6        True         18
# 7        True          8
# 8        True         23
# 9        True         13
# 10       True         19
# 11       True         25
# 12       True          4
# 13       True          7
# 14       True          6
# 15       True         27
# 16       True         10
# 17       True          9
# 18       True         22
# 19       True         26
# 20       True         17
# 21       True          3
# 22       True         24
# 23       True         20
# 24       True         12
# 25       True         15
# 26       True          1
# 27       True          2

# %%
predictor.feature_importance(train)
# Out:
# Computing feature importance via permutation shuffling for 17 features using 5000 rows with 5 shuffle sets...
# 	90.69s	= Expected runtime (18.14s per shuffle set)
# 	31.4s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                                 importance    stddev       p_value  n  \
# Weight                             0.33584  0.004746  4.786094e-09  5
# BMI                                0.23964  0.005228  2.715715e-08  5
# Gender                             0.13232  0.004514  1.622083e-07  5
# FCVC                               0.12912  0.002524  1.752013e-08  5
# TUE                                0.05812  0.004505  4.295938e-06  5
# FAF                                0.04464  0.004883  1.691571e-05  5
# Age                                0.03920  0.002821  3.197934e-06  5
# CH2O                               0.01948  0.001487  4.046018e-06  5
# Height                             0.01532  0.001741  1.968615e-05  5
# CALC                               0.01256  0.001905  6.156815e-05  5
# NCP                                0.01224  0.001946  7.419499e-05  5
# family_history_with_overweight     0.00744  0.002202  8.221060e-04  5
# FAVC                               0.00744  0.001315  1.122311e-04  5
# MTRANS                             0.00696  0.001071  6.531731e-05  5
# CAEC                               0.00636  0.000573  7.805837e-06  5
# SCC                                0.00356  0.000607  9.737495e-05  5
# SMOKE                              0.00012  0.000179  1.040000e-01  5
#
#                                 p99_high   p99_low
# Weight                          0.345613  0.326067
# BMI                             0.250404  0.228876
# Gender                          0.141613  0.123027
# FCVC                            0.134318  0.123922
# TUE                             0.067395  0.048845
# FAF                             0.054695  0.034585
# Age                             0.045009  0.033391
# CH2O                            0.022542  0.016418
# Height                          0.018905  0.011735
# CALC                            0.016482  0.008638
# NCP                             0.016247  0.008233
# family_history_with_overweight  0.011974  0.002906
# FAVC                            0.010147  0.004733
# MTRANS                          0.009166  0.004754
# CAEC                            0.007539  0.005181
# SCC                             0.004809  0.002311
# SMOKE                           0.000488 -0.000248

# %%
predictions = predictor.predict(test)

# %%
submission = pd.DataFrame()
submission["id"] = test_ids
submission[TARGET] = predictions

# write submission dataframe to .csv file 
submission.to_csv('submission.csv', index = False)
submission.head()
# Out:
#       id          NObeyesdad
# 0  20758     Obesity_Type_II
# 1  20759  Overweight_Level_I
# 2  20760    Obesity_Type_III
# 3  20761      Obesity_Type_I
# 4  20762    Obesity_Type_III
